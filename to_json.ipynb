# %%
import pandas as pd

# %%
data1 = pd.read_csv('true_dataset.csv')
data2 = pd.read_csv('fake_dataset.csv')

# %%
frames = [data1, data2]
result = pd.concat(frames).drop_duplicates().reset_index(drop=True)
result
# Out:
#        created_at             date       user_id        username  \
# 0    1.655550e+12  6/18/2022 16:42  5.550737e+07       tvOneNews
# 1    1.655510e+12   6/18/2022 7:19  4.173094e+07        VIVAcoid
# 2    1.655210e+12  6/14/2022 19:53  7.052240e+17   Berita_Corona
# 3    1.655210e+12  6/14/2022 19:40  1.712898e+07    CNNIndonesia
# 4    1.655180e+12  6/14/2022 12:06  1.403680e+18      BroAkbar27
# ..            ...              ...           ...             ...
# 195  1.593470e+12   6/30/2020 5:34  1.271030e+18  PPSBojongsoang
# 196  1.593470e+12   6/30/2020 5:27  8.856793e+07       djody2010
# 197  1.593470e+12   6/30/2020 5:26  1.040659e+08  katalogpromosi
# 198  1.593470e+12   6/30/2020 5:23  2.396490e+08          ASR20_
# 199  1.593470e+12   6/30/2020 5:14  7.709325e+08  EbenEzer170596
#
#                      name                                              tweet  \
# 0                   tvOne  apa penyebab varian baru virus corona kembali ...
# ...

# %%
result.to_json("dataset.json")

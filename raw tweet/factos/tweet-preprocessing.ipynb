# %%
#library

import pandas as pd
import contractions
import re
import string
from cleantext import clean
from nltk.tokenize import word_tokenize
import nltk
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize

# %%
# #data cleansing

# def cleansing(tweet):

#     #remove RT Tag
#     t1 = re.sub('RT\s', '', tweet)
    
#     #remove @_username
#     t2 = re.sub('\B@\w+', '', t1)
    
#     #remove emoji
#     emoji_pattern = re.compile("["
#         u"\U0001F600-\U0001F64F"  # emoticons
#         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#         u"\U0001F680-\U0001F6FF"  # transport & map symbols
#         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
#                            "]+", flags=re.UNICODE)
    
#     t3 = emoji_pattern.sub(r'', t2)
    
#     #remove URL (https:// or https://)
#     t4 = re.sub(r'\S*https?:\S*', '', t3)
    
#     #remove #_something
#     t5 = re.sub('#+', '', t4)
    
#     #lower case each letter / case folding
#     t6 = t5.lower()
    
#     #alphabets only, exclude numbers and special characters
#     t7 = re.sub(r'[^a-zA-Z]', ' ', t6)
    
#     #Replace contractions with their extended forms
#     t8 = contractions.fix(t7)
    
#     t9 = t8.strip()
    
#     t10 = re.sub(r"\b[a-zA-Z]\b", "", t9)
#     return t10

# %%
file = input('Enter File Name:') #raw_tweet

df = pd.read_csv('raw_tweets_' + file + '.csv', usecols=['created_at', 'date', 'user_id', 'username', 'name', 'tweet', 'link'])
df
# Out:
# Enter File Name:varian covid yang membahayakan
#       created_at                 date              user_id         username  \
# 0   1.644986e+12  2022-02-16 11:25:58  1279248910276419585     HarianDisway
# 1   1.644423e+12  2022-02-09 23:15:03             79130206          jpnncom
# 2   1.644387e+12  2022-02-09 13:03:19            985931010  abcaustralia_id
# 3   1.644057e+12  2022-02-05 17:30:00  1238375641902268416         jagak_id
# 4   1.643522e+12  2022-01-30 12:57:04             78226378      shitlicious
# 5   1.639803e+12  2021-12-18 11:45:00  1037280932347006978     Rudycraft666
# 6   1.639705e+12  2021-12-17 08:31:55            280794125  kalimaya_malang
# 7   1.639361e+12  2021-12-13 09:08:02           3278095975       Slashers_s
# 8   1.638138e+12  2021-11-29 05:27:59           1379431842      MrsRachelIn
# 9   1.637986e+12  2021-11-27 11:07:00             75077164     voaindonesia
# 10  1.637973e+12  2021-11-27 07:35:18             75077164     voaindonesia
# 11  1.630540e+12  2021-09-02 06:41:20  1138068019035328512       ravinabila
# 12  1.629896e+12  2021-08-25 20:00:02             39933002  officialnova_id
# 13  1.629851e+12  2021-08-25 07:30:00             39933002  officialnova_id
# 14  1.629687e+12  2021-08-23 09:44:18            176733069    TalkToPhillip
# 15  1.628742e+12  2021-08-12 11:23:29            124390203        beritaKBR
# 16  1.628592e+12  2021-08-10 17:40:29             42199532         UMonline
# 17  1.627275e+12  2021-07-26 11:42:52           3043246526    XinwenMetroTV
# 18  1.627107e+12  2021-07-24 13:07:25            414597892     B_Hendratmo1
# 19  1.626411e+12  2021-07-16 11:47:43            129142186       maurisarab
# 20  1.625556e+12  2021-07-06 14:12:56  1133635707036086273       ampunbang_
# 21  1.625526e+12  2021-07-06 06:03:43             18129942       tempodotco
# 22  1.625370e+12  2021-07-04 10:33:05            194059434    rachmanndsyah
# 23  1.625025e+12  2021-06-30 10:53:05            155161935         Desty007
# 24  1.624541e+12  2021-06-24 20:17:31            315753047        VrHunter_
# 25  1.618472e+12  2021-04-15 14:30:37           3271146871      XHIndonesia
# 26  1.615457e+12  2021-03-11 17:10:31            456426648    merdekadotcom
# 27  1.611822e+12  2021-01-28 15:22:38            182189888    UKinIndonesia
# 28  1.609386e+12  2020-12-31 10:41:59            255866913     hariankompas
#
#                               name  \
# 0                    𝗛𝗔𝗥𝗜𝗔𝗡 𝗗𝗜𝗦𝗪𝗔𝗬
# 1                         JPNN.com
# 2                    ABC Indonesia
# 3                            Jagak
# 4                            Alitt
# 5                 rakyat Indonesia
# 6   Radio Kalimaya Bhaskara Malang
# 7                           29_kai
# 8                  indri Yahya⚘🇮🇩🕊
# 9                    VOA Indonesia
# 10                   VOA Indonesia
# 11                               b
# 12                            NOVA
# 13                            NOVA
# 14               Phillip Sekuritas
# 15                             KBR
# 16                 Utusan Malaysia
# 17                    Metro Xinwen
# 18                     B_Hendratmo
# 19                      Onta Kribo
# 20                           april
# 21                        tempo.co
# 22               Pace Naturalisasi
# 23             Anisa Deasty Malela
# 24                  Yusly si Wolfy
# 25                Xinhua Indonesia
# 26                     Merdeka.com
# 27                 UK in Indonesia
# 28                   Harian Kompas
#
#                                                 tweet  \
# 0   Berdamai dengan Covid-19 masih bergantung pada...
# 1   Seorang ekonom yang menganalisa data COVID sej...
# 2   Seorang ekonom yang menganalisa data COVID sej...
# 3   Indonesia telah resmi memasuki gelombang ketig...
# 4   Udah nemu bbrp teman yang positive covid akhir...
# 5   Kita masyarakat yang taat dan tidak keluar neg...
# 6   Presiden Joko Widodo menyatakan, sejauh ini Co...
# 7   @r7olles @maman1965 Ini bukan masalah bombasti...
# 8   @Nicho_Silalahi Ini orang , tau ga sih semua n...
# 9   Mutasi baru COVID-19 yang dinamakan B11529 dit...
# 10  Mutasi baru COVID-19 yang dinamakan B11529 dit...
# 11  Vaksin Merah Putih memberikan hasil yang cukup...
# 12  Bermutasi dan makin membahayakan, kenali 10 va...
# 13  Bermutasi dan makin membahayakan, kenali 10 va...
# 14  ....kebutuhan untuk penarikan (tapering) paket...
# 15  Saat ini Indonesia masih menjadi pusat penular...
# 16  “Negara masih dalam kemelut memerangi Covid-19...
# 17  Presiden Joko Widodo menyatakan bahwa PPKM Dar...
# 18  @YRadianto @hansssolo @TomCruzz555 @ImamGozhal...
# 19  Ternyata, bukan Varian COVID-19 yang membahaya...
# 20  @njing56 gak membahayakan? covid aja udah ada ...
# 21  Wakil Gubernur DKI Jakarta Ahmad Riza Patria m...
# 22  Yang masih tra percaya sama covid atau yg kare...
# 23  WHO memperingatkan semua masyarakat dunia, kal...
# 24  Se ngeri itu Varian Covid sekarang, tiap kelua...
# 25  Riset menunjukkan varian COVID-19 yang pertama...
# 26  Epidemiolog: Sulit Buktikan Kasus Corona B117 ...
# 27  Inggris menawarkan keahlian genomik terdepan u...
# 28  Tahun 2021, fokus dunia diyakini masih tertuju...
#
#                                                  link
# 0   https://twitter.com/HarianDisway/status/149380...
# 1   https://twitter.com/jpnncom/status/14914455493...
# 2   https://twitter.com/abcaustralia_id/status/149...
# 3   https://twitter.com/jagak_id/status/1489909163...
# 4   https://twitter.com/shitlicious/status/1487666...
# 5   https://twitter.com/Rudycraft666/status/147206...
# 6   https://twitter.com/kalimaya_malang/status/147...
# 7   https://twitter.com/Slashers_s/status/14702138...
# 8   https://twitter.com/MrsRachelIn/status/1465085...
# 9   https://twitter.com/voaindonesia/status/146444...
# 10  https://twitter.com/voaindonesia/status/146439...
# 11  https://twitter.com/ravinabila/status/14332134...
# 12  https://twitter.com/officialnova_id/status/143...
# 13  https://twitter.com/officialnova_id/status/143...
# 14  https://twitter.com/TalkToPhillip/status/14296...
# 15  https://twitter.com/beritaKBR/status/142567427...
# 16  https://twitter.com/UMonline/status/1425044375...
# 17  https://twitter.com/XinwenMetroTV/status/14195...
# 18  https://twitter.com/B_Hendratmo1/status/141881...
# 19  https://twitter.com/maurisarab/status/14158959...
# 20  https://twitter.com/ampunbang_/status/14123085...
# 21  https://twitter.com/tempodotco/status/14121854...
# 22  https://twitter.com/rachmanndsyah/status/14115...
# 23  https://twitter.com/Desty007/status/1410083945...
# 24  https://twitter.com/VrHunter_/status/140805166...
# 25  https://twitter.com/XHIndonesia/status/1382597...
# 26  https://twitter.com/merdekadotcom/status/13699...
# 27  https://twitter.com/UKinIndonesia/status/13547...
# 28  https://twitter.com/hariankompas/status/134448...

# %%
#case_folding
df['tweet'] = df['tweet'].str.lower()
df
# Out:
#       created_at                 date              user_id         username  \
# 0   1.644986e+12  2022-02-16 11:25:58  1279248910276419585     HarianDisway
# 1   1.644423e+12  2022-02-09 23:15:03             79130206          jpnncom
# 2   1.644387e+12  2022-02-09 13:03:19            985931010  abcaustralia_id
# 3   1.644057e+12  2022-02-05 17:30:00  1238375641902268416         jagak_id
# 4   1.643522e+12  2022-01-30 12:57:04             78226378      shitlicious
# 5   1.639803e+12  2021-12-18 11:45:00  1037280932347006978     Rudycraft666
# 6   1.639705e+12  2021-12-17 08:31:55            280794125  kalimaya_malang
# 7   1.639361e+12  2021-12-13 09:08:02           3278095975       Slashers_s
# 8   1.638138e+12  2021-11-29 05:27:59           1379431842      MrsRachelIn
# 9   1.637986e+12  2021-11-27 11:07:00             75077164     voaindonesia
# 10  1.637973e+12  2021-11-27 07:35:18             75077164     voaindonesia
# 11  1.630540e+12  2021-09-02 06:41:20  1138068019035328512       ravinabila
# 12  1.629896e+12  2021-08-25 20:00:02             39933002  officialnova_id
# 13  1.629851e+12  2021-08-25 07:30:00             39933002  officialnova_id
# 14  1.629687e+12  2021-08-23 09:44:18            176733069    TalkToPhillip
# 15  1.628742e+12  2021-08-12 11:23:29            124390203        beritaKBR
# 16  1.628592e+12  2021-08-10 17:40:29             42199532         UMonline
# 17  1.627275e+12  2021-07-26 11:42:52           3043246526    XinwenMetroTV
# 18  1.627107e+12  2021-07-24 13:07:25            414597892     B_Hendratmo1
# 19  1.626411e+12  2021-07-16 11:47:43            129142186       maurisarab
# 20  1.625556e+12  2021-07-06 14:12:56  1133635707036086273       ampunbang_
# 21  1.625526e+12  2021-07-06 06:03:43             18129942       tempodotco
# 22  1.625370e+12  2021-07-04 10:33:05            194059434    rachmanndsyah
# 23  1.625025e+12  2021-06-30 10:53:05            155161935         Desty007
# 24  1.624541e+12  2021-06-24 20:17:31            315753047        VrHunter_
# 25  1.618472e+12  2021-04-15 14:30:37           3271146871      XHIndonesia
# 26  1.615457e+12  2021-03-11 17:10:31            456426648    merdekadotcom
# 27  1.611822e+12  2021-01-28 15:22:38            182189888    UKinIndonesia
# 28  1.609386e+12  2020-12-31 10:41:59            255866913     hariankompas
#
#                               name  \
# 0                    𝗛𝗔𝗥𝗜𝗔𝗡 𝗗𝗜𝗦𝗪𝗔𝗬
# 1                         JPNN.com
# 2                    ABC Indonesia
# 3                            Jagak
# 4                            Alitt
# 5                 rakyat Indonesia
# 6   Radio Kalimaya Bhaskara Malang
# 7                           29_kai
# 8                  indri Yahya⚘🇮🇩🕊
# 9                    VOA Indonesia
# 10                   VOA Indonesia
# 11                               b
# 12                            NOVA
# 13                            NOVA
# 14               Phillip Sekuritas
# 15                             KBR
# 16                 Utusan Malaysia
# 17                    Metro Xinwen
# 18                     B_Hendratmo
# 19                      Onta Kribo
# 20                           april
# 21                        tempo.co
# 22               Pace Naturalisasi
# 23             Anisa Deasty Malela
# 24                  Yusly si Wolfy
# 25                Xinhua Indonesia
# 26                     Merdeka.com
# 27                 UK in Indonesia
# 28                   Harian Kompas
#
#                                                 tweet  \
# 0   berdamai dengan covid-19 masih bergantung pada...
# 1   seorang ekonom yang menganalisa data covid sej...
# 2   seorang ekonom yang menganalisa data covid sej...
# 3   indonesia telah resmi memasuki gelombang ketig...
# 4   udah nemu bbrp teman yang positive covid akhir...
# 5   kita masyarakat yang taat dan tidak keluar neg...
# 6   presiden joko widodo menyatakan, sejauh ini co...
# 7   @r7olles @maman1965 ini bukan masalah bombasti...
# 8   @nicho_silalahi ini orang , tau ga sih semua n...
# 9   mutasi baru covid-19 yang dinamakan b11529 dit...
# 10  mutasi baru covid-19 yang dinamakan b11529 dit...
# 11  vaksin merah putih memberikan hasil yang cukup...
# 12  bermutasi dan makin membahayakan, kenali 10 va...
# 13  bermutasi dan makin membahayakan, kenali 10 va...
# 14  ....kebutuhan untuk penarikan (tapering) paket...
# 15  saat ini indonesia masih menjadi pusat penular...
# 16  “negara masih dalam kemelut memerangi covid-19...
# 17  presiden joko widodo menyatakan bahwa ppkm dar...
# 18  @yradianto @hansssolo @tomcruzz555 @imamgozhal...
# 19  ternyata, bukan varian covid-19 yang membahaya...
# 20  @njing56 gak membahayakan? covid aja udah ada ...
# 21  wakil gubernur dki jakarta ahmad riza patria m...
# 22  yang masih tra percaya sama covid atau yg kare...
# 23  who memperingatkan semua masyarakat dunia, kal...
# 24  se ngeri itu varian covid sekarang, tiap kelua...
# 25  riset menunjukkan varian covid-19 yang pertama...
# 26  epidemiolog: sulit buktikan kasus corona b117 ...
# 27  inggris menawarkan keahlian genomik terdepan u...
# 28  tahun 2021, fokus dunia diyakini masih tertuju...
#
#                                                  link
# 0   https://twitter.com/HarianDisway/status/149380...
# 1   https://twitter.com/jpnncom/status/14914455493...
# 2   https://twitter.com/abcaustralia_id/status/149...
# 3   https://twitter.com/jagak_id/status/1489909163...
# 4   https://twitter.com/shitlicious/status/1487666...
# 5   https://twitter.com/Rudycraft666/status/147206...
# 6   https://twitter.com/kalimaya_malang/status/147...
# 7   https://twitter.com/Slashers_s/status/14702138...
# 8   https://twitter.com/MrsRachelIn/status/1465085...
# 9   https://twitter.com/voaindonesia/status/146444...
# 10  https://twitter.com/voaindonesia/status/146439...
# 11  https://twitter.com/ravinabila/status/14332134...
# 12  https://twitter.com/officialnova_id/status/143...
# 13  https://twitter.com/officialnova_id/status/143...
# 14  https://twitter.com/TalkToPhillip/status/14296...
# 15  https://twitter.com/beritaKBR/status/142567427...
# 16  https://twitter.com/UMonline/status/1425044375...
# 17  https://twitter.com/XinwenMetroTV/status/14195...
# 18  https://twitter.com/B_Hendratmo1/status/141881...
# 19  https://twitter.com/maurisarab/status/14158959...
# 20  https://twitter.com/ampunbang_/status/14123085...
# 21  https://twitter.com/tempodotco/status/14121854...
# 22  https://twitter.com/rachmanndsyah/status/14115...
# 23  https://twitter.com/Desty007/status/1410083945...
# 24  https://twitter.com/VrHunter_/status/140805166...
# 25  https://twitter.com/XHIndonesia/status/1382597...
# 26  https://twitter.com/merdekadotcom/status/13699...
# 27  https://twitter.com/UKinIndonesia/status/13547...
# 28  https://twitter.com/hariankompas/status/134448...

# %%
#tokenizing
import string 
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

#tokenizing
def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['tweet'] = df['tweet'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['tweet'] = df['tweet'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df['tweet'] = df['tweet'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['tweet'] = df['tweet'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['tweet'] = df['tweet'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['tweet'] = df['tweet'].apply(remove_single_char)

# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['tweet_preproc'] = df['tweet'].apply(word_tokenize_wrapper)

df.head()
# Out:
#      created_at                 date              user_id         username  \
# 0  1.644986e+12  2022-02-16 11:25:58  1279248910276419585     HarianDisway
# 1  1.644423e+12  2022-02-09 23:15:03             79130206          jpnncom
# 2  1.644387e+12  2022-02-09 13:03:19            985931010  abcaustralia_id
# 3  1.644057e+12  2022-02-05 17:30:00  1238375641902268416         jagak_id
# 4  1.643522e+12  2022-01-30 12:57:04             78226378      shitlicious
#
#             name                                              tweet  \
# 0  𝗛𝗔𝗥𝗜𝗔𝗡 𝗗𝗜𝗦𝗪𝗔𝗬  berdamai dengan covid masih bergantung pada mu...
# 1       JPNN.com  seorang ekonom yang menganalisa data covid sej...
# 2  ABC Indonesia  seorang ekonom yang menganalisa data covid sej...
# 3          Jagak  indonesia telah resmi memasuki gelombang ketig...
# 4          Alitt  udah nemu bbrp teman yang positive covid akhir...
#
#                                                 link  \
# 0  https://twitter.com/HarianDisway/status/149380...
# 1  https://twitter.com/jpnncom/status/14914455493...
# 2  https://twitter.com/abcaustralia_id/status/149...
# 3  https://twitter.com/jagak_id/status/1489909163...
# 4  https://twitter.com/shitlicious/status/1487666...
#
#                                        tweet_preproc
# 0  [berdamai, dengan, covid, masih, bergantung, p...
# 1  [seorang, ekonom, yang, menganalisa, data, cov...
# 2  [seorang, ekonom, yang, menganalisa, data, cov...
# 3  [indonesia, telah, resmi, memasuki, gelombang,...
# 4  [udah, nemu, bbrp, teman, yang, positive, covi...

# %%
# #filtering/stopword removal
# from nltk.corpus import stopwords

# # ----------------------- get stopword from NLTK stopword -------------------------------
# # get stopword indonesia
# list_stopwords = stopwords.words('indonesian')


# # ---------------------------- manualy add stopword  ------------------------------------
# # append additional stopword
# list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
#                        'kalo', 'amp', 'biar', 'bikin', 'bilang', 
#                        'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
#                        'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
#                        'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
#                        'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
#                        '&amp', 'yah'])

# # ----------------------- add stopword from txt file ------------------------------------
# # read txt stopword using pandas
# # txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)

# # convert stopword string to list & append additional stopword
# # list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# # ---------------------------------------------------------------------------------------

# # convert list to dictionary
# list_stopwords = set(list_stopwords)

# #remove stopword pada list token
# def stopwords_removal(words):
#     return [word for word in words if word not in list_stopwords]

# df['tweet_preproc'] = df['tweet_preproc'].apply(stopwords_removal) 


# df.head()

# %%
#text_normalize
normalizad_word = pd.read_excel("normalisasi_text.xlsx")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df['tweet_preproc'] = df['tweet_preproc'].apply(normalized_term)

df.head(10)
# Out:
#      created_at                 date              user_id         username  \
# 0  1.644986e+12  2022-02-16 11:25:58  1279248910276419585     HarianDisway
# 1  1.644423e+12  2022-02-09 23:15:03             79130206          jpnncom
# 2  1.644387e+12  2022-02-09 13:03:19            985931010  abcaustralia_id
# 3  1.644057e+12  2022-02-05 17:30:00  1238375641902268416         jagak_id
# 4  1.643522e+12  2022-01-30 12:57:04             78226378      shitlicious
# 5  1.639803e+12  2021-12-18 11:45:00  1037280932347006978     Rudycraft666
# 6  1.639705e+12  2021-12-17 08:31:55            280794125  kalimaya_malang
# 7  1.639361e+12  2021-12-13 09:08:02           3278095975       Slashers_s
# 8  1.638138e+12  2021-11-29 05:27:59           1379431842      MrsRachelIn
# 9  1.637986e+12  2021-11-27 11:07:00             75077164     voaindonesia
#
#                              name  \
# 0                   𝗛𝗔𝗥𝗜𝗔𝗡 𝗗𝗜𝗦𝗪𝗔𝗬
# 1                        JPNN.com
# 2                   ABC Indonesia
# 3                           Jagak
# 4                           Alitt
# 5                rakyat Indonesia
# 6  Radio Kalimaya Bhaskara Malang
# 7                          29_kai
# 8                 indri Yahya⚘🇮🇩🕊
# 9                   VOA Indonesia
#
#                                                tweet  \
# 0  berdamai dengan covid masih bergantung pada mu...
# 1  seorang ekonom yang menganalisa data covid sej...
# 2  seorang ekonom yang menganalisa data covid sej...
# 3  indonesia telah resmi memasuki gelombang ketig...
# 4  udah nemu bbrp teman yang positive covid akhir...
# 5  kita masyarakat yang taat dan tidak keluar neg...
# 6  presiden joko widodo menyatakan sejauh ini cov...
# 7  ini bukan masalah bombastis atau tidak judulny...
# 8  silalahi ini orang tau ga sih semua negara sed...
# 9  mutasi baru covid yang dinamakan  ditemukan di...
#
#                                                 link  \
# 0  https://twitter.com/HarianDisway/status/149380...
# 1  https://twitter.com/jpnncom/status/14914455493...
# 2  https://twitter.com/abcaustralia_id/status/149...
# 3  https://twitter.com/jagak_id/status/1489909163...
# 4  https://twitter.com/shitlicious/status/1487666...
# 5  https://twitter.com/Rudycraft666/status/147206...
# 6  https://twitter.com/kalimaya_malang/status/147...
# 7  https://twitter.com/Slashers_s/status/14702138...
# 8  https://twitter.com/MrsRachelIn/status/1465085...
# 9  https://twitter.com/voaindonesia/status/146444...
#
#                                        tweet_preproc
# 0  [berdamai, dengan, covid, masih, bergantung, p...
# 1  [seorang, ekonom, yang, menganalisa, data, cov...
# 2  [seorang, ekonom, yang, menganalisa, data, cov...
# 3  [indonesia, telah, resmi, memasuki, gelombang,...
# 4  [udah, nemu, bbrp, teman, yang, positive, covi...
# 5  [kita, masyarakat, yang, taat, dan, tidak, kel...
# 6  [presiden, joko, widodo, menyatakan, sejauh, i...
# 7  [ini, bukan, masalah, bombastis, atau, tidak, ...
# 8  [silalahi, ini, orang, tahu, tidak, sih, semua...
# 9  [mutasi, baru, covid, yang, dinamakan, ditemuk...

# %%
# for i, r in df.iterrows():
#     y = cleansing(r['tweet'])
#     df.loc[i, 'tweet'] = y
    
# df.head()

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['tweet_preproc']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['tweet_preproc'] = df['tweet_preproc'].swifter.apply(get_stemmed_term)
df
# Out:
# 368
# ------------------------
# berdamai : damai
# dengan : dengan
# covid : covid
# masih : masih
# bergantung : gantung
# pada : pada
# mutasi : mutasi
# virus : virus
# selama : lama
# tidak : tidak
# ada : ada
# varian : varian
# baru : baru
# yang : yang
# membahayakan : bahaya
# indonesia : indonesia
# kapan : kapan
# baca : baca
# selengkapnya : lengkap
# di : di
# seorang : orang
# ekonom : ekonom
# menganalisa : menganalisa
# data : data
# sejak : sejak
# awal : awal
# pandemi : pandemi
# memperkirakan : kira
# omicron : omicron
# akan : akan
# menjadi : jadi
# terakhir : akhir
# negaranegara : negaranegara
# sudah : sudah
# memiliki : milik
# tingkat : tingkat
# vaksinasi : vaksinasi
# tinggi : tinggi
# telah : telah
# resmi : resmi
# memasuki : pasuk
# gelombang : gelombang
# ketiga : tiga
# setelah : telah
# kenaikan : naik
# kasus : kasus
# cukup : cukup
# signifikan : signifikan
# dalam : dalam
# sepekan : pek
# penyebaran : sebar
# cepat : cepat
# sangat : sangat
# apalagi : apalagi
# gejala : gejala
# lebih : lebih
# menyerupai : rupa
# flu : flu
# dibandingkan : banding
# lainnya : lain
# udah : udah
# nemu : nemu
# bbrp : bbrp
# teman : teman
# positive : positive
# akhir : akhir
# ini : ini
# dan : dan
# semua : semua
# gejalanya : gejala
# ringan : ringan
# beda : beda
# banget : banget
# ama : ama
# pas : pas
# rame : rame
# delta : delta
# kemarin : kemarin
# semoga : moga
# virusnya : virus
# bermutasi : mutasi
# melemah : lemah
# terus : terus
# tetap : tetap
# waspada : waspada
# karena : karena
# nih : nih
# bagi : bagi
# orang : orang
# belum : belum
# vaksin : vaksin
# punya : punya
# komorbid : komorbid
# kita : kita
# masyarakat : masyarakat
# taat : taat
# keluar : keluar
# negeri : negeri
# turut : turut
# korban : korban
# dari : dari
# penularan : tular
# pemerintah : perintah
# harus : harus
# menindak : tindak
# pelaku : laku
# perjalanan : jalan
# lalai : lalai
# dapat : dapat
# presiden : presiden
# joko : joko
# widodo : widodo
# menyatakan : nyata
# sejauh : jauh
# atau : atau
# terdeteksi : deteksi
# meski : meski
# nyawa : nyawa
# bukan : bukan
# masalah : masalah
# bombastis : bombastis
# judulnya : judul
# bagaimana : bagaimana
# mungkin : mungkin
# seseorang : orang
# bisa : bisa
# situasi : situasi
# adanya : ada
# chance : chance
# membawa : bawa
# negerinya : negeri
# bisanya : bisa
# mendapatkan : dapat
# hukuman : hukum
# membuat : buat
# jera : jera
# sehingga : sehingga
# hal : hal
# tsb : tsb
# silalahi : silalahi
# tahu : tahu
# sih : sih
# negara : negara
# sedang : sedang
# dengam : dengam
# melanda : landa
# duniakalau : duniakalau
# loh : loh
# peduli : peduli
# diri : diri
# seridaknya : seridaknya
# jangan : jangan
# lain : lain
# demo : demo
# galang : galang
# massa : massa
# mbuat : mbuat
# cluster : cluster
# kamu : kamu
# tanggung : tanggung
# jawab : jawab
# bila : bila
# terjadi : jadi
# lonjakan : lonjak
# dinamakan : nama
# ditemukan : temu
# wilayah : wilayah
# selatan : selatan
# afrika : afrika
# berdasarkan : dasar
# penelitian : teliti
# sejumlah : jumlah
# pakar : pakar
# mengemukakan : muka
# berpotensi : potensi
# merah : merah
# putih : putih
# memberikan : beri
# hasil : hasil
# menjanjikan : janji
# menangkal : tangkal
# bahkan : bahkan
# dikenal : kenal
# menyebar : sebar
# saat : saat
# proses : proses
# uji : uji
# klinis : klinis
# berikut : ikut
# adalah : adalah
# fakta : fakta
# tentang : tentang
# makin : makin
# kenali : kenal
# dunia : dunia
# kebutuhan : butuh
# untuk : untuk
# penarikan : tari
# tapering : tapering
# paket : paket
# stimulus : stimulus
# moneter : moneter
# jika : jika
# ternyata : nyata
# ekonomi : ekonomi
# as : as
# disclaimer : disclaimer
# on : on
# pusat : pusat
# pengendalian : kendali
# maksimal : maksimal
# dikhawatirkan : khawatir
# menciptakan : cipta
# kemelut : kemelut
# memerangi : rang
# kebelakangan : belakang
# baharu : baharu
# merebak : rebak
# boleh : boleh
# apa : apa
# jua : jua
# tindakan : tindak
# aktiviti : aktiviti
# menyukarkan : sukar
# penjarakan : penjara
# fizikal : fizikal
# bahwa : bahwa
# ppkm : ppkm
# darurat : darurat
# level : level
# berhasil : hasil
# memperbaiki : baik
# demikian : demikian
# jokowi : jokowi
# meminta : minta
# selalu : selalu
# terhadap : hadap
# terutama : utama
# setuju : tuju
# bingitz : bingitz
# yth : yth
# bapak : bapak
# polri : polri
# tni : tni
# bongkar : bongkar
# dalang : dalang
# kesehatan : sehat
# keselamatan : selamat
# rakyat : rakyat
# tetapi : tetapi
# kebijakan : bijak
# seluruh : seluruh
# canda : canda
# aja : aja
# banyak : banyak
# meninggal : tinggal
# juga : juga
# hadeh : hadeh
# wakil : wakil
# gubernur : gubernur
# dki : dki
# jakarta : jakarta
# ahmad : ahmad
# riza : riza
# patria : patria
# menyebut : sebut
# yaitu : yaitu
# menular : tular
# tra : tra
# percaya : percaya
# sama : sama
# muda : muda
# jadi : jadi
# merasa : rasa
# coba : coba
# pikir : pikir
# lagi : lagi
# jauh : jauh
# berbahaya : bahaya
# tua : tua
# kematian : mati
# stop : stop
# tenang : tenang
# rumah : rumah
# who : who
# memperingatkan : ingat
# kalau : kalau
# tapi : tapi
# buat : buat
# kalian : kalian
# patuh : patuh
# protokol : protokol
# panik : panik
# berlebihan : lebih
# se : se
# ngeri : ngeri
# itu : itu
# sekarang : sekarang
# tiap : tiap
# kosan : kosan
# wajib : wajib
# ngeliat : ngeliat
# mobil : mobil
# jenazah : jenazah
# stay : stay
# safe : safe
# ya : ya
# guys : guys
# silahkan : silah
# tolong : tolong
# riset : riset
# menunjukkan : tunjuk
# pertama : pertama
# kali : kali
# teridentifikasi : identifikasi
# inggris : inggris
# kucing : kucing
# anjing : anjing
# tersebut : sebut
# meningkatkan : tingkat
# risiko : risiko
# inflamasi : inflamasi
# otot : otot
# jantung : jantung
# hewan : hewan
# klik : klik
# video : video
# mendengarkan : dengar
# informasi : informasi
# epidemiolog : epidemiolog
# sulit : sulit
# buktikan : bukti
# corona : corona
# kepulangan : pulang
# wni : wni
# beberapa : beberapa
# pernyataan : nyata
# umum : umum
# mengatakan : kata
# dibanding : banding
# sars : sars
# cov : cov
# seperti : seperti
# namun : namun
# berdampak : dampak
# holistik : holistik
# menawarkan : tawar
# keahlian : ahli
# genomik : genomik
# terdepan : depan
# mengidentifikasi : identifikasi
# platform : platform
# membantu : bantu
# perubahan : ubah
# serta : serta
# peringatan : ingat
# dini : dini
# tahun : tahun
# fokus : fokus
# diyakini : yakin
# tertuju : tuju
# penanggulangan : tanggulang
# menjelang : jelang
# justru : justru
# ditengarai : tengara
# berita : berita
# kemunculan : muncul
# ganas : ganas
# {'berdamai': 'damai', 'dengan': 'dengan', 'covid': 'covid', 'masih': 'masih', 'bergantung': 'gantung', 'pada': 'pada', 'mutasi': 'mutasi', 'virus': 'virus', 'selama': 'lama', 'tidak': 'tidak', 'ada': 'ada', 'varian': 'varian', 'baru': 'baru', 'yang': 'yang', 'membahayakan': 'bahaya', 'indonesia': 'indonesia', 'kapan': 'kapan', 'baca': 'baca', 'selengkapnya': 'lengkap', 'di': 'di', 'seorang': 'orang', 'ekonom': 'ekonom', 'menganalisa': 'menganalisa', 'data': 'data', 'sejak': 'sejak', 'awal': 'awal', 'pandemi': 'pandemi', 'memperkirakan': 'kira', 'omicron': 'omicron', 'akan': 'akan', 'menjadi': 'jadi', 'terakhir': 'akhir', 'negaranegara': 'negaranegara', 'sudah': 'sudah', 'memiliki': 'milik', 'tingkat': 'tingkat', 'vaksinasi': 'vaksinasi', 'tinggi': 'tinggi', 'telah': 'telah', 'resmi': 'resmi', 'memasuki': 'pasuk', 'gelombang': 'gelombang', 'ketiga': 'tiga', 'setelah': 'telah', 'kenaikan': 'naik', 'kasus': 'kasus', 'cukup': 'cukup', 'signifikan': 'signifikan', 'dalam': 'dalam', 'sepekan': 'pek', 'penyebaran': 'sebar', 'cepat': 'cepat', 'sangat': 'sangat', 'apalagi': 'apalagi', 'gejala': 'gejala', 'lebih': 'lebih', 'menyerupai': 'rupa', 'flu': 'flu', 'dibandingkan': 'banding', 'lainnya': 'lain', 'udah': 'udah', 'nemu': 'nemu', 'bbrp': 'bbrp', 'teman': 'teman', 'positive': 'positive', 'akhir': 'akhir', 'ini': 'ini', 'dan': 'dan', 'semua': 'semua', 'gejalanya': 'gejala', 'ringan': 'ringan', 'beda': 'beda', 'banget': 'banget', 'ama': 'ama', 'pas': 'pas', 'rame': 'rame', 'delta': 'delta', 'kemarin': 'kemarin', 'semoga': 'moga', 'virusnya': 'virus', 'bermutasi': 'mutasi', 'melemah': 'lemah', 'terus': 'terus', 'tetap': 'tetap', 'waspada': 'waspada', 'karena': 'karena', 'nih': 'nih', 'bagi': 'bagi', 'orang': 'orang', 'belum': 'belum', 'vaksin': 'vaksin', 'punya': 'punya', 'komorbid': 'komorbid', 'kita': 'kita', 'masyarakat': 'masyarakat', 'taat': 'taat', 'keluar': 'keluar', 'negeri': 'negeri', 'turut': 'turut', 'korban': 'korban', 'dari': 'dari', 'penularan': 'tular', 'pemerintah': 'perintah', 'harus': 'harus', 'menindak': 'tindak', 'pelaku': 'laku', 'perjalanan': 'jalan', 'lalai': 'lalai', 'dapat': 'dapat', 'presiden': 'presiden', 'joko': 'joko', 'widodo': 'widodo', 'menyatakan': 'nyata', 'sejauh': 'jauh', 'atau': 'atau', 'terdeteksi': 'deteksi', 'meski': 'meski', 'nyawa': 'nyawa', 'bukan': 'bukan', 'masalah': 'masalah', 'bombastis': 'bombastis', 'judulnya': 'judul', 'bagaimana': 'bagaimana', 'mungkin': 'mungkin', 'seseorang': 'orang', 'bisa': 'bisa', 'situasi': 'situasi', 'adanya': 'ada', 'chance': 'chance', 'membawa': 'bawa', 'negerinya': 'negeri', 'bisanya': 'bisa', 'mendapatkan': 'dapat', 'hukuman': 'hukum', 'membuat': 'buat', 'jera': 'jera', 'sehingga': 'sehingga', 'hal': 'hal', 'tsb': 'tsb', 'silalahi': 'silalahi', 'tahu': 'tahu', 'sih': 'sih', 'negara': 'negara', 'sedang': 'sedang', 'dengam': 'dengam', 'melanda': 'landa', 'duniakalau': 'duniakalau', 'loh': 'loh', 'peduli': 'peduli', 'diri': 'diri', 'seridaknya': 'seridaknya', 'jangan': 'jangan', 'lain': 'lain', 'demo': 'demo', 'galang': 'galang', 'massa': 'massa', 'mbuat': 'mbuat', 'cluster': 'cluster', 'kamu': 'kamu', 'tanggung': 'tanggung', 'jawab': 'jawab', 'bila': 'bila', 'terjadi': 'jadi', 'lonjakan': 'lonjak', 'dinamakan': 'nama', 'ditemukan': 'temu', 'wilayah': 'wilayah', 'selatan': 'selatan', 'afrika': 'afrika', 'berdasarkan': 'dasar', 'penelitian': 'teliti', 'sejumlah': 'jumlah', 'pakar': 'pakar', 'mengemukakan': 'muka', 'berpotensi': 'potensi', 'merah': 'merah', 'putih': 'putih', 'memberikan': 'beri', 'hasil': 'hasil', 'menjanjikan': 'janji', 'menangkal': 'tangkal', 'bahkan': 'bahkan', 'dikenal': 'kenal', 'menyebar': 'sebar', 'saat': 'saat', 'proses': 'proses', 'uji': 'uji', 'klinis': 'klinis', 'berikut': 'ikut', 'adalah': 'adalah', 'fakta': 'fakta', 'tentang': 'tentang', 'makin': 'makin', 'kenali': 'kenal', 'dunia': 'dunia', 'kebutuhan': 'butuh', 'untuk': 'untuk', 'penarikan': 'tari', 'tapering': 'tapering', 'paket': 'paket', 'stimulus': 'stimulus', 'moneter': 'monete ...
# ------------------------
# Pandas Apply:   0%|          | 0/29 [00:00<?, ?it/s]
#       created_at                 date              user_id         username  \
# 0   1.644986e+12  2022-02-16 11:25:58  1279248910276419585     HarianDisway
# 1   1.644423e+12  2022-02-09 23:15:03             79130206          jpnncom
# 2   1.644387e+12  2022-02-09 13:03:19            985931010  abcaustralia_id
# 3   1.644057e+12  2022-02-05 17:30:00  1238375641902268416         jagak_id
# 4   1.643522e+12  2022-01-30 12:57:04             78226378      shitlicious
# 5   1.639803e+12  2021-12-18 11:45:00  1037280932347006978     Rudycraft666
# 6   1.639705e+12  2021-12-17 08:31:55            280794125  kalimaya_malang
# 7   1.639361e+12  2021-12-13 09:08:02           3278095975       Slashers_s
# 8   1.638138e+12  2021-11-29 05:27:59           1379431842      MrsRachelIn
# 9   1.637986e+12  2021-11-27 11:07:00             75077164     voaindonesia
# 10  1.637973e+12  2021-11-27 07:35:18             75077164     voaindonesia
# 11  1.630540e+12  2021-09-02 06:41:20  1138068019035328512       ravinabila
# 12  1.629896e+12  2021-08-25 20:00:02             39933002  officialnova_id
# 13  1.629851e+12  2021-08-25 07:30:00             39933002  officialnova_id
# 14  1.629687e+12  2021-08-23 09:44:18            176733069    TalkToPhillip
# 15  1.628742e+12  2021-08-12 11:23:29            124390203        beritaKBR
# 16  1.628592e+12  2021-08-10 17:40:29             42199532         UMonline
# 17  1.627275e+12  2021-07-26 11:42:52           3043246526    XinwenMetroTV
# 18  1.627107e+12  2021-07-24 13:07:25            414597892     B_Hendratmo1
# 19  1.626411e+12  2021-07-16 11:47:43            129142186       maurisarab
# 20  1.625556e+12  2021-07-06 14:12:56  1133635707036086273       ampunbang_
# 21  1.625526e+12  2021-07-06 06:03:43             18129942       tempodotco
# 22  1.625370e+12  2021-07-04 10:33:05            194059434    rachmanndsyah
# 23  1.625025e+12  2021-06-30 10:53:05            155161935         Desty007
# 24  1.624541e+12  2021-06-24 20:17:31            315753047        VrHunter_
# 25  1.618472e+12  2021-04-15 14:30:37           3271146871      XHIndonesia
# 26  1.615457e+12  2021-03-11 17:10:31            456426648    merdekadotcom
# 27  1.611822e+12  2021-01-28 15:22:38            182189888    UKinIndonesia
# 28  1.609386e+12  2020-12-31 10:41:59            255866913     hariankompas
#
#                               name  \
# 0                    𝗛𝗔𝗥𝗜𝗔𝗡 𝗗𝗜𝗦𝗪𝗔𝗬
# 1                         JPNN.com
# 2                    ABC Indonesia
# 3                            Jagak
# 4                            Alitt
# 5                 rakyat Indonesia
# 6   Radio Kalimaya Bhaskara Malang
# 7                           29_kai
# 8                  indri Yahya⚘🇮🇩🕊
# 9                    VOA Indonesia
# 10                   VOA Indonesia
# 11                               b
# 12                            NOVA
# 13                            NOVA
# 14               Phillip Sekuritas
# 15                             KBR
# 16                 Utusan Malaysia
# 17                    Metro Xinwen
# 18                     B_Hendratmo
# 19                      Onta Kribo
# 20                           april
# 21                        tempo.co
# 22               Pace Naturalisasi
# 23             Anisa Deasty Malela
# 24                  Yusly si Wolfy
# 25                Xinhua Indonesia
# 26                     Merdeka.com
# 27                 UK in Indonesia
# 28                   Harian Kompas
#
#                                                 tweet  \
# 0   berdamai dengan covid masih bergantung pada mu...
# 1   seorang ekonom yang menganalisa data covid sej...
# 2   seorang ekonom yang menganalisa data covid sej...
# 3   indonesia telah resmi memasuki gelombang ketig...
# 4   udah nemu bbrp teman yang positive covid akhir...
# 5   kita masyarakat yang taat dan tidak keluar neg...
# 6   presiden joko widodo menyatakan sejauh ini cov...
# 7   ini bukan masalah bombastis atau tidak judulny...
# 8   silalahi ini orang tau ga sih semua negara sed...
# 9   mutasi baru covid yang dinamakan  ditemukan di...
# 10  mutasi baru covid yang dinamakan  ditemukan di...
# 11  vaksin merah putih memberikan hasil yang cukup...
# 12  bermutasi dan makin membahayakan kenali varian...
# 13  bermutasi dan makin membahayakan kenali varian...
# 14  kebutuhan untuk penarikan tapering paket stimu...
# 15  saat ini indonesia masih menjadi pusat penular...
# 16  negara masih dalam kemelut memerangi covid keb...
# 17  presiden joko widodo menyatakan bahwa ppkm dar...
# 18  setuju bingitz yth bapak polri tni bongkar dal...
# 19  ternyata bukan varian covid yang membahayakan ...
# 20  gak membahayakan covid aja udah ada varian bar...
# 21  wakil gubernur dki jakarta ahmad riza patria m...
# 22  yang masih tra percaya sama covid atau yg kare...
# 23  who memperingatkan semua masyarakat dunia kala...
# 24  se ngeri itu varian covid sekarang tiap keluar...
# 25  riset menunjukkan varian covid yang pertama ka...
# 26  epidemiolog sulit buktikan kasus corona  di in...
# 27  inggris menawarkan keahlian genomik terdepan u...
# 28  tahun fokus dunia diyakini masih tertuju pada ...
#
#                                                  link  \
# 0   https://twitter.com/HarianDisway/status/149380...
# 1   https://twitter.com/jpnncom/status/14914455493...
# 2   https://twitter.com/abcaustralia_id/status/149...
# 3   https://twitter.com/jagak_id/status/1489909163...
# 4   https://twitter.com/shitlicious/status/1487666...
# 5   https://twitter.com/Rudycraft666/status/147206...
# 6   https://twitter.com/kalimaya_malang/status/147...
# 7   https://twitter.com/Slashers_s/status/14702138...
# 8   https://twitter.com/MrsRachelIn/status/1465085...
# 9   https://twitter.com/voaindonesia/status/146444...
# 10  https://twitter.com/voaindonesia/status/146439...
# 11  https://twitter.com/ravinabila/status/14332134...
# 12  https://twitter.com/officialnova_id/status/143...
# 13  https://twitter.com/officialnova_id/status/143...
# 14  https://twitter.com/TalkToPhillip/status/14296...
# 15  https://twitter.com/beritaKBR/status/142567427...
# 16  https://twitter.com/UMonline/status/1425044375...
# 17  https://twitter.com/XinwenMetroTV/status/14195...
# 18  https://twitter.com/B_Hendratmo1/status/141881...
# 19  https://twitter.com/maurisarab/status/14158959...
# 20  https://twitter.com/ampunbang_/status/14123085...
# 21  https://twitter.com/tempodotco/status/14121854...
# 22  https://twitter.com/rachmanndsyah/status/14115...
# 23  https://twitter.com/Desty007/status/1410083945...
# 24  https://twitter.com/VrHunter_/status/140805166...
# 25  https://twitter.com/XHIndonesia/status/1382597...
# 26  https://twitter.com/merdekadotcom/status/13699...
# 27  https://twitter.com/UKinIndonesia/status/13547...
# 28  https://twitter.com/hariankompas/status/134448...
#
#                                         tweet_preproc
# 0   [damai, dengan, covid, masih, gantung, pada, m...
# 1   [orang, ekonom, yang, menganalisa, data, covid...
# 2   [orang, ekonom, yang, menganalisa, data, covid...
# 3   [indonesia, telah, resmi, pasuk, gelombang, ti...
# 4   [udah, nemu, bbrp, teman, yang, positive, covi...
# 5   [kita, masyarakat, yang, taat, dan, tidak, kel...
# 6   [presiden, joko, widodo, nyata, jauh, ini, cov...
# 7   [ini, bukan, masalah, bombastis, atau, tidak, ...
# 8   [silalahi, ini, orang, tahu, tidak, sih, semua...
# 9   [mutasi, baru, covid, yang, nama, temu, di, wi...
# 10  [mutasi, baru, covid, yang, nama, temu, di, wi...
# 11  [vaksin, merah, putih, beri, hasil, yang, cuku...
# 12  [mutasi, dan, makin, bahaya, kenal, varian, co...
# 13  [mutasi, dan, makin, bahaya, kenal, varian, co...
# 14  [butuh, untuk, tari, tapering, paket, stimulus...
# 15  [saat, ini, indonesia, masih, jadi, pusat, tul...
# 16  [negara, masih, dalam, kemelut, rang, covid, b...
# 17  [presiden, joko, widodo, nyata, bahwa, ppkm, d...
# 18  [tuju, bingitz, yth, bapak, polri, tni, bongka...
# 19  [nyata, bukan, varian, covid, yang, bahaya, te...
# 20  [tidak, bahaya, covid, aja, udah, ada, varian,...
# 21  [wakil, gubernur, dki, jakarta, ahmad, riza, p...
# 22  [yang, masih, tra, percaya, sama, covid, atau,...
# 23  [who, ingat, semua, masyarakat, dunia, kalau, ...
# 24  [se, ngeri, itu, varian, covid, sekarang, tiap...
# 25  [riset, tunjuk, varian, covid, yang, pertama, ...
# 26  [epidemiolog, sulit, bukti, kasus, corona, di,...
# 27  [inggris, tawar, ahli, genomik, depan, untuk, ...
# 28  [tahun, fokus, dunia, yakin, masih, tuju, pada...

# %%
#POS Tagger Dictionary
# post_dict = {'J/':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}

# %%
# def token_stop_pos(text):
#     tags = pos_tag(word_tokenize(text))
#     list_stopwords = stopwords.words('indonesian')
#     list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
#                        'kalo', 'amp', 'biar', 'bikin', 'bilang', 
#                        'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
#                        'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
#                        'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
#                        'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
#                        '&amp', 'yah', 'klo'])
#     newlist = []
#     for word, tag in tags:
#         if word.lower() not in list_stopwords:
#             newlist.append(tuple([word, post_dict.get(tag[0])]))
#     return newlist

# %%
# df['POS tagged'] = df['tweet'].apply(token_stop_pos)
# df.head()

# %%
export = input('Enter File Name:') #cleaned_tweet

df.to_csv("cleaned_tweets_" + export + ".csv", index=False)
# Out:
# Enter File Name:varian covid yang membahayakan

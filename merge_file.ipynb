# %%
import pandas as pd

# %%
data1 = pd.read_csv('labeled_tweets_masker kompas.csv')
data2 = pd.read_csv('labeled_tweets_masker liputan6.csv')
data3 = pd.read_csv('labeled_tweets_psbb kompas.csv')
data4 = pd.read_csv('labeled_tweets_psbb liputan6.csv')

# %%
data1.drop(data1[data1['Label'] == 0].index, inplace = True)
data1
# Out:
#       created_at                 date   user_id   username        name  \
# 0   1.648608e+12  2022-03-30 09:32:06  23343960  kompascom  Kompas.com
# 1   1.648547e+12  2022-03-29 16:36:05  23343960  kompascom  Kompas.com
# 2   1.648374e+12  2022-03-27 16:47:32  23343960  kompascom  Kompas.com
# 3   1.648170e+12  2022-03-25 07:55:41  23343960  kompascom  Kompas.com
# 4   1.648120e+12  2022-03-24 18:02:42  23343960  kompascom  Kompas.com
# ..           ...                  ...       ...        ...         ...
# 75  1.643679e+12  2022-02-01 08:23:09  23343960  kompascom  Kompas.com
# 76  1.643626e+12  2022-01-31 17:48:13  23343960  kompascom  Kompas.com
# 77  1.643614e+12  2022-01-31 14:21:07  23343960  kompascom  Kompas.com
# 78  1.643585e+12  2022-01-31 06:17:44  23343960  kompascom  Kompas.com
# 79  1.643575e+12  2022-01-31 03:30:00  23343960  kompascom  Kompas.com
#
#                                                 tweet  \
# 0   meski pasar tanah abang padat  pengunjung teta...
# ...

# %%
data2.drop(data2[data2['Label'] == 0].index, inplace = True)
data2
# Out:
#       created_at                 date   user_id        username      name  \
# 0   1.648538e+12  2022-03-29 14:16:03  47596019  liputan6dotcom  LIPUTAN6
# 1   1.648530e+12  2022-03-29 11:57:05  47596019  liputan6dotcom  LIPUTAN6
# 2   1.648167e+12  2022-03-25 07:08:06  47596019  liputan6dotcom  LIPUTAN6
# 3   1.648110e+12  2022-03-24 15:24:05  47596019  liputan6dotcom  LIPUTAN6
# 4   1.648041e+12  2022-03-23 20:12:36  47596019  liputan6dotcom  LIPUTAN6
# 5   1.648034e+12  2022-03-23 18:16:07  47596019  liputan6dotcom  LIPUTAN6
# 6   1.647607e+12  2022-03-18 19:38:33  47596019  liputan6dotcom  LIPUTAN6
# 7   1.647414e+12  2022-03-16 14:05:37  47596019  liputan6dotcom  LIPUTAN6
# 8   1.647317e+12  2022-03-15 11:08:05  47596019  liputan6dotcom  LIPUTAN6
# 9   1.647261e+12  2022-03-14 19:27:04  47596019  liputan6dotcom  LIPUTAN6
# 10  1.647204e+12  2022-03-14 03:46:03  47596019  liputan6dotcom  LIPUTAN6
# 11  1.646921e+12  2022-03-10 21:07:07  47596019  liputan6dotcom  LIPUTAN6
# ...

# %%
data3.drop(data3[data3['Label'] == 0].index, inplace = True)
data3
# Out:
#       created_at                 date   user_id   username        name  \
# 0   1.596202e+12  2020-07-31 20:20:34  23343960  kompascom  Kompas.com
# 1   1.596182e+12  2020-07-31 15:00:04  23343960  kompascom  Kompas.com
# 2   1.596152e+12  2020-07-31 06:31:04  23343960  kompascom  Kompas.com
# 3   1.596150e+12  2020-07-31 06:00:33  23343960  kompascom  Kompas.com
# 4   1.596112e+12  2020-07-30 19:18:32  23343960  kompascom  Kompas.com
# 5   1.596109e+12  2020-07-30 18:42:04  23343960  kompascom  Kompas.com
# 6   1.596107e+12  2020-07-30 18:05:33  23343960  kompascom  Kompas.com
# 7   1.596105e+12  2020-07-30 17:22:34  23343960  kompascom  Kompas.com
# 8   1.596093e+12  2020-07-30 14:08:33  23343960  kompascom  Kompas.com
# 9   1.596077e+12  2020-07-30 09:46:00  23343960  kompascom  Kompas.com
# 10  1.596073e+12  2020-07-30 08:42:32  23343960  kompascom  Kompas.com
# 11  1.596010e+12  2020-07-29 15:05:33  23343960  kompascom  Kompas.com
# ...

# %%
data4.drop(data4[data4['Label'] == 0].index, inplace = True)
data2
# Out:
#       created_at                 date   user_id        username      name  \
# 0   1.648538e+12  2022-03-29 14:16:03  47596019  liputan6dotcom  LIPUTAN6
# 1   1.648530e+12  2022-03-29 11:57:05  47596019  liputan6dotcom  LIPUTAN6
# 2   1.648167e+12  2022-03-25 07:08:06  47596019  liputan6dotcom  LIPUTAN6
# 3   1.648110e+12  2022-03-24 15:24:05  47596019  liputan6dotcom  LIPUTAN6
# 4   1.648041e+12  2022-03-23 20:12:36  47596019  liputan6dotcom  LIPUTAN6
# 5   1.648034e+12  2022-03-23 18:16:07  47596019  liputan6dotcom  LIPUTAN6
# 6   1.647607e+12  2022-03-18 19:38:33  47596019  liputan6dotcom  LIPUTAN6
# 7   1.647414e+12  2022-03-16 14:05:37  47596019  liputan6dotcom  LIPUTAN6
# 8   1.647317e+12  2022-03-15 11:08:05  47596019  liputan6dotcom  LIPUTAN6
# 9   1.647261e+12  2022-03-14 19:27:04  47596019  liputan6dotcom  LIPUTAN6
# 10  1.647204e+12  2022-03-14 03:46:03  47596019  liputan6dotcom  LIPUTAN6
# 11  1.646921e+12  2022-03-10 21:07:07  47596019  liputan6dotcom  LIPUTAN6
# ...

# %%
frames = [data1, data2, data3, data4]
result = pd.concat(frames).drop_duplicates().reset_index(drop=True)
result
# Out:
#        created_at                 date   user_id        username        name  \
# 0    1.648608e+12  2022-03-30 09:32:06  23343960       kompascom  Kompas.com
# 1    1.648547e+12  2022-03-29 16:36:05  23343960       kompascom  Kompas.com
# 2    1.648374e+12  2022-03-27 16:47:32  23343960       kompascom  Kompas.com
# 3    1.648170e+12  2022-03-25 07:55:41  23343960       kompascom  Kompas.com
# 4    1.648120e+12  2022-03-24 18:02:42  23343960       kompascom  Kompas.com
# ..            ...                  ...       ...             ...         ...
# 255  1.592378e+12  2020-06-17 14:10:03  47596019  liputan6dotcom    LIPUTAN6
# 256  1.592367e+12  2020-06-17 11:11:02  47596019  liputan6dotcom    LIPUTAN6
# 257  1.592355e+12  2020-06-17 07:42:33  47596019  liputan6dotcom    LIPUTAN6
# 258  1.592354e+12  2020-06-17 07:35:04  47596019  liputan6dotcom    LIPUTAN6
# 259  1.592349e+12  2020-06-17 06:07:33  47596019  liputan6dotcom    LIPUTAN6
#
# ...

# %%
label = []
for index, row in result.iterrows():
    if row['Label'] == 1:
        label.append('FAKTA')
    else:
        label.append('HOAKS')
result['Label'] = label
result
# Out:
#        created_at                 date   user_id        username        name  \
# 0    1.648608e+12  2022-03-30 09:32:06  23343960       kompascom  Kompas.com
# 1    1.648547e+12  2022-03-29 16:36:05  23343960       kompascom  Kompas.com
# 2    1.648374e+12  2022-03-27 16:47:32  23343960       kompascom  Kompas.com
# 3    1.648170e+12  2022-03-25 07:55:41  23343960       kompascom  Kompas.com
# 4    1.648120e+12  2022-03-24 18:02:42  23343960       kompascom  Kompas.com
# ..            ...                  ...       ...             ...         ...
# 255  1.592378e+12  2020-06-17 14:10:03  47596019  liputan6dotcom    LIPUTAN6
# 256  1.592367e+12  2020-06-17 11:11:02  47596019  liputan6dotcom    LIPUTAN6
# 257  1.592355e+12  2020-06-17 07:42:33  47596019  liputan6dotcom    LIPUTAN6
# 258  1.592354e+12  2020-06-17 07:35:04  47596019  liputan6dotcom    LIPUTAN6
# 259  1.592349e+12  2020-06-17 06:07:33  47596019  liputan6dotcom    LIPUTAN6
#
# ...

# %%
result.to_csv("true_dataset.csv", index=False)

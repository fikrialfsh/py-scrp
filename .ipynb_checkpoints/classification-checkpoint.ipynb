# %%
import pandas as pd
import numpy as np

# %%
truenews = pd.read_csv('true_dataset.csv')
fakenews = pd.read_csv('fake_dataset.csv')

# %%
fakenews.head()
# Out:
#      created_at                 date              user_id        username  \
# 0  1.653843e+12  2022-05-29 23:42:07            215839128  hendra_roestoe
# 1  1.653725e+12  2022-05-28 15:11:02  1362243328276762626        wahiidin
# 2  1.653711e+12  2022-05-28 11:05:26  1528282299091275777       UmJihan69
# 3  1.653672e+12  2022-05-28 00:24:34  1426251818527444992    KaiAndromeda
# 4  1.653642e+12  2022-05-27 15:58:27  1131257783486013440        MasN4jib
#
#                    name                                              tweet  \
# 0  HendraRoestoeMulyana  saya lebih percaya kpd dr  siti fadilah supari...
# 1              wahiidin   smoga sj bukan jd bisnis  ada yg bilang klo b...
# 2              Um Jihan   logikanya  kenapa ke afrika  afrika daya beli...
# 3          Mandroid|Kai  wajar   komnas ini ada hanya utk menguatkan bi...
# 4                   71B                         bisnis vaksin ga diitung
#
#                                                 link  \
# 0  https://twitter.com/hendra_roestoe/status/1530...
# 1  https://twitter.com/wahiidin/status/1530461634...
# 2  https://twitter.com/UmJihan69/status/153039982...
# 3  https://twitter.com/KaiAndromeda/status/153023...
# 4  https://twitter.com/MasN4jib/status/1530111177...
#
#                                           POS tagged  Label
# 0  [('percaya', 'n'), ('kpd', 'n'), ('dr', 'n'), ...  HOAKS
# 1  [('smoga', 'n'), ('sj', 'n'), ('jd', 'n'), ('b...  HOAKS
# 2  [('logikanya', 'n'), ('afrika', None), ('afrik...  HOAKS
# 3  [('wajar', 'n'), ('komnas', 'n'), ('utk', None...  HOAKS
# 4  [('bisnis', 'n'), ('vaksin', 'n'), ('ga', 'n')...  HOAKS

# %%
truenews.head()
# Out:
#      created_at                 date              user_id       username  \
# 0  1.655545e+12  2022-06-18 16:42:27             55507370      tvOneNews
# 1  1.655512e+12  2022-06-18 07:19:23             41730943       VIVAcoid
# 2  1.655211e+12  2022-06-14 19:53:52   705224376422010881  Berita_Corona
# 3  1.655210e+12  2022-06-14 19:40:52             17128975   CNNIndonesia
# 4  1.655183e+12  2022-06-14 12:06:11  1403680930842042374     BroAkbar27
#
#             name                                              tweet  \
# 0          tvOne  apa penyebab varian baru virus corona kembali ...
# 1       VivaCoid  virus corona atau covid    terus bermutasi hin...
# 2  Berita Corona  kenapa varian dan subvarian baru virus corona ...
# 3  CNN Indonesia  kenapa varian dan subvarian baru virus corona ...
# 4        𝕬𝖐𝖇𝖆𝖗   pemerintah mewaspadai munculnya virus corona v...
#
#                                                 link  \
# 0  https://twitter.com/tvOneNews/status/153809478...
# 1  https://twitter.com/VIVAcoid/status/1537953082...
# 2  https://twitter.com/Berita_Corona/status/15366...
# 3  https://twitter.com/CNNIndonesia/status/153669...
# 4  https://twitter.com/BroAkbar27/status/15365757...
#
#                                           POS tagged  Label
# 0  [('penyebab', 'n'), ('varian', None), ('virus'...  FAKTA
# 1  [('virus', 'n'), ('corona', 'n'), ('covid', 'n...  FAKTA
# 2  [('varian', None), ('subvarian', None), ('viru...  FAKTA
# 3  [('varian', None), ('subvarian', None), ('viru...  FAKTA
# 4  [('pemerintah', 'n'), ('mewaspadai', 'n'), ('m...  FAKTA

# %%
fakenews.describe()
# Out:
#          created_at       user_id
# count  2.100000e+01  2.100000e+01
# mean   1.611728e+12  8.532136e+17
# std    3.721863e+10  5.835958e+17
# min    1.580215e+12  1.631267e+08
# 25%    1.580277e+12  2.150563e+09
# 50%    1.580297e+12  1.085367e+18
# 75%    1.653622e+12  1.340273e+18
# max    1.653843e+12  1.530026e+18

# %%
truenews.describe()
# Out:
#          created_at       user_id
# count  1.600000e+01  1.600000e+01
# mean   1.655059e+12  7.217575e+17
# std    3.088498e+08  6.324454e+17
# min    1.654498e+12  1.712898e+07
# 25%    1.654874e+12  1.240248e+08
# 50%    1.655169e+12  7.324586e+17
# 75%    1.655190e+12  1.364348e+18
# max    1.655545e+12  1.485879e+18

# %%
truenews['Fakta/Hoaks']='Fakta'
fakenews['Fakta/Hoaks']='Hoaks'

# %%
# Combine the 2 DataFrames into a single data frame
news = pd.concat([truenews, fakenews])
news["Artikel"] = news["name"] + news["tweet"]
news.sample(frac = 1)
# Out:
#       created_at                 date              user_id         username  \
# 0   1.655545e+12  2022-06-18 16:42:27             55507370        tvOneNews
# 13  1.654606e+12  2022-06-07 19:53:20   705224376422010881    Berita_Corona
# 15  1.580277e+12  2020-01-29 12:48:06  1140215810230640640       apasihlex_
# 11  1.580296e+12  2020-01-29 18:00:38   908262533131202561     Janahara_com
# 7   1.653609e+12  2022-05-27 06:55:50  1340273082926125057        ZPembayun
# 11  1.654912e+12  2022-06-11 08:45:54  1098777698917203968  kominfomagetan1
# 18  1.580256e+12  2020-01-29 06:57:01  1220455209169612800  ArisBudiSulist1
# 20  1.580215e+12  2020-01-28 19:29:43  1085366701514866688       rfldrkptr_
# 14  1.654571e+12  2022-06-07 09:58:11  1484076613566627842    ridea81837744
# 14  1.580283e+12  2020-01-29 14:27:56            163126674  RinaAnak_Bundaa
# 15  1.654498e+12  2022-06-06 13:52:06  1485547534097731592     IndriDiana12
# 9   1.580303e+12  2020-01-29 20:03:28   895339916174925824    mhmmd_khaedir
# 4   1.653642e+12  2022-05-27 15:58:27  1131257783486013440         MasN4jib
# 9   1.655130e+12  2022-06-13 21:15:09             69183155         detikcom
# 10  1.655117e+12  2022-06-13 17:50:24            142305302      tribunmedan
# 6   1.655171e+12  2022-06-14 08:50:27           2890721762      LINIKINI_ID
# 3   1.653672e+12  2022-05-28 00:24:34  1426251818527444992     KaiAndromeda
# 12  1.654759e+12  2022-06-09 14:10:51  1485878996181319680       mamisarah7
# 5   1.653622e+12  2022-05-27 10:33:59  1530026270582419457         Orasi_Id
# 13  1.580296e+12  2020-01-29 17:59:36  1073072054767767552      bagerrrrrrr
# 0   1.653843e+12  2022-05-29 23:42:07            215839128   hendra_roestoe
# 5   1.655174e+12  2022-06-14 09:32:06   759692754985242625         kumparan
# 2   1.655211e+12  2022-06-14 19:53:52   705224376422010881    Berita_Corona
# 8   1.653582e+12  2022-05-26 23:16:31  1344682642961141760    AndiPitopang6
# 2   1.653711e+12  2022-05-28 11:05:26  1528282299091275777        UmJihan69
# 3   1.655210e+12  2022-06-14 19:40:52             17128975     CNNIndonesia
# 17  1.580268e+12  2020-01-29 10:25:02            864608695        najibonel
# 6   1.653612e+12  2022-05-27 07:42:00            366549945   andri_anto7121
# 19  1.580217e+12  2020-01-28 20:12:15           2150563345       arksaputra
# 4   1.655183e+12  2022-06-14 12:06:11  1403680930842042374       BroAkbar27
# 8   1.655169e+12  2022-06-14 08:03:19  1068779253351632896       Alin_tan11
# 12  1.580296e+12  2020-01-29 18:00:35   830184202737889281     endonesia_id
# 1   1.653725e+12  2022-05-28 15:11:02  1362243328276762626         wahiidin
# 16  1.580270e+12  2020-01-29 10:45:53            262026799     MSNindonesia
# 10  1.580297e+12  2020-01-29 18:25:34  1101571504460840960          difzein
# 7   1.655169e+12  2022-06-14 08:17:09  1351236840066609171         Naraera1
# 1   1.655512e+12  2022-06-18 07:19:23             41730943         VIVAcoid
#
#                     name                                              tweet  \
# 0                  tvOne  apa penyebab varian baru virus corona kembali ...
# 13         Berita Corona  virus grismo varian baru corona muncul di swed...
# 15                  Woy.   wuhan jiayou   virus corona menyebar lewat hp...
# 11          Janahara.com  waspada  virus corona menyebar lewat hp cina  ...
# 7        Zidnia Pembayun                        amp  bisnis vaksin pastinya
# 11        kominfomagetan  jangan abai  jangan panik  tetap waspadai vari...
# 18    Aris Budi Sulistyo              virus corona menyebar lewat hp xiomi
# 20    Rifaldi Raka Putra  virus corona menyebar lewat hp xiaomi  jika ad...
# 14                 ridea   tetap harus waspada dengan virus corona varia...
# 14           Rina Syafri  soal virus corona menyebar lewat hp xiaomi  ik...
# 15            IndriDiana   tetap harus waspada dengan virus corona varia...
# 9                Khaedir  masa ada yang percaya sih virus corona menyeba...
# 4                    71B                         bisnis vaksin ga diitung
# 9               detikcom  varian baru corona omicron ba   dan ba   kini ...
# 10          Tribun Medan  ada varian baru virus corona  indonesia bersia...
# 6            LINIKINI_ID  commuters  hati hati ada varian baru nih     v...
# 3           Mandroid|Kai  wajar   komnas ini ada hanya utk menguatkan bi...
# 12            mami sarah   tetap harus waspada dengan virus corona varia...
# 5               Orasi.Id   virus ohvirus  padahal kita bisa menolak dari...
# 13                 bager               virus corona menyebar lewat hp xiomi
# 0   HendraRoestoeMulyana  saya lebih percaya kpd dr  siti fadilah supari...
# 5               kumparan  aturan ini akan berubah bila ada varian baru v...
# 2          Berita Corona  kenapa varian dan subvarian baru virus corona ...
# 8          Andi Pitopang            bentar lagi bisnis vaksin cacar monyet
# 2               Um Jihan   logikanya  kenapa ke afrika  afrika daya beli...
# 3          CNN Indonesia  kenapa varian dan subvarian baru virus corona ...
# 17                6:00pm              virus corona menyebar lewat hp xiaomi
# 6              andrianto  itu penjanjian tipuan yg di gunakan utk penghu...
# 19           Adi Saputra  daro joke virus corona menyebar lewat hp xiaom...
# 4                𝕬𝖐𝖇𝖆𝖗   pemerintah mewaspadai munculnya virus corona v...
# 8               Alin Tan  lawanvarianbaru  tanda  omricon varian baru  g...
# 12          Endonesia.id  waspada  virus corona menyebar lewat hp cina  ...
# 1               wahiidin   smoga sj bukan jd bisnis  ada yg bilang klo b...
# 16          MSNIndonesia  viral virus corona menyebar lewat hp xiaomi da...
# 10              Dif Zein  viral virus corona menyebar lewat hp xiaomi  i...
# 7                Nara€ra  meski kenaikan kasus covid    di indonesia bel...
# 1               VivaCoid  virus corona atau covid    terus bermutasi hin...
#
#                                                  link  \
# 0   https://twitter.com/tvOneNews/status/153809478...
# 13  https://twitter.com/Berita_Corona/status/15341...
# 15  https://twitter.com/apasihlex_/status/12223959...
# 11  https://twitter.com/Janahara_com/status/122247...
# 7   https://twitter.com/ZPembayun/status/152997462...
# 11  https://twitter.com/kominfomagetan1/status/153...
# 18  https://twitter.com/ArisBudiSulist1/status/122...
# 20  https://twitter.com/rfldrkptr_/status/12221346...
# 14  https://twitter.com/ridea81837744/status/15340...
# 14  https://twitter.com/RinaAnak_Bundaa/status/122...
# 15  https://twitter.com/IndriDiana12/status/153370...
# 9   https://twitter.com/mhmmd_khaedir/status/12225...
# 4   https://twitter.com/MasN4jib/status/1530111177...
# 9   https://twitter.com/detikcom/status/1536351472...
# 10  https://twitter.com/tribunmedan/status/1536299...
# 6   https://twitter.com/LINIKINI_ID/status/1536526...
# 3   https://twitter.com/KaiAndromeda/status/153023...
# 12  https://twitter.com/mamisarah7/status/15347951...
# 5   https://twitter.com/Orasi_Id/status/1530029521...
# 13  https://twitter.com/bagerrrrrrr/status/1222474...
# 0   https://twitter.com/hendra_roestoe/status/1530...
# 5   https://twitter.com/kumparan/status/1536536931...
# 2   https://twitter.com/Berita_Corona/status/15366...
# 8   https://twitter.com/AndiPitopang6/status/15298...
# 2   https://twitter.com/UmJihan69/status/153039982...
# 3   https://twitter.com/CNNIndonesia/status/153669...
# 17  https://twitter.com/najibonel/status/122235997...
# 6   https://twitter.com/andri_anto7121/status/1529...
# 19  https://twitter.com/arksaputra/status/12221453...
# 4   https://twitter.com/BroAkbar27/status/15365757...
# 8   https://twitter.com/Alin_tan11/status/15365145...
# 12  https://twitter.com/endonesia_id/status/122247...
# 1   https://twitter.com/wahiidin/status/1530461634...
# 16  https://twitter.com/MSNindonesia/status/122236...
# 10  https://twitter.com/difzein/status/12224809037...
# 7   https://twitter.com/Naraera1/status/1536518068...
# 1   https://twitter.com/VIVAcoid/status/1537953082...
#
#                                            POS tagged  Label Fakta/Hoaks  \
# 0   [('penyebab', 'n'), ('varian', None), ('virus'...  FAKTA       Fakta
# 13  [('virus', 'n'), ('grismo', 'n'), ('varian', N...  FAKTA       Fakta
# 15  [('wuhan', 'n'), ('jiayou', 'n'), ('virus', 'n...  HOAKS       Hoaks
# 11  [('waspada', 'n'), ('virus', 'n'), ('corona', ...  HOAKS       Hoaks
# 7   [('amp', 'n'), ('bisnis', 'n'), ('vaksin', 'n'...  HOAKS       Hoaks
# 11  [('abai', 'v'), ('panik', None), ('waspadai', ...  FAKTA       Fakta
# 18  [('virus', 'n'), ('corona', 'n'), ('menyebar',...  HOAKS       Hoaks
# 20  [('virus', 'n'), ('corona', 'n'), ('menyebar',...  HOAKS       Hoaks
# 14  [('waspada', 'n'), ('virus', 'n'), ('corona', ...  FAKTA       Fakta
# 14  [('virus', 'n'), ('corona', 'n'), ('menyebar',...  HOAKS       Hoaks
# 15  [('waspada', 'n'), ('virus', 'n'), ('corona', ...  FAKTA       Fakta
# 9   [('percaya', 'n'), ('sih', 'n'), ('virus', 'n'...  HOAKS       Hoaks
# 4   [('bisnis', 'n'), ('vaksin', 'n'), ('ga', 'n')...  HOAKS       Hoaks
# 9   [('varian', None), ('corona', 'n'), ('omicron'...  FAKTA       Fakta
# 10  [('varian', None), ('virus', 'n'), ('corona', ...  FAKTA       Fakta
# 6   [('commuters', 'n'), ('hati', 'v'), ('hati', N...  FAKTA       Fakta
# 3   [('wajar', 'n'), ('komnas', 'n'), ('utk', None...  HOAKS       Hoaks
# 12  [('waspada', 'n'), ('virus', 'n'), ('corona', ...  FAKTA       Fakta
# 5   [('virus', 'n'), ('ohvirus', 'n'), ('menolak',...  HOAKS       Hoaks
# 13  [('virus', 'n'), ('corona', 'n'), ('menyebar',...  HOAKS       Hoaks
# 0   [('percaya', 'n'), ('kpd', 'n'), ('dr', 'n'), ...  HOAKS       Hoaks
# 5   [('aturan', 'n'), ('berubah', 'n'), ('varian',...  FAKTA       Fakta
# 2   [('varian', None), ('subvarian', None), ('viru...  FAKTA       Fakta
# 8   [('bentar', 'n'), ('bisnis', 'n'), ('vaksin', ...  HOAKS       Hoaks
# 2   [('logikanya', 'n'), ('afrika', None), ('afrik...  HOAKS       Hoaks
# 3   [('varian', None), ('subvarian', None), ('viru...  FAKTA       Fakta
# 17  [('virus', 'n'), ('corona', 'n'), ('menyebar',...  HOAKS       Hoaks
# 6   [('penjanjian', None), ('tipuan', 'n'), ('yg',...  HOAKS       Hoaks
# 19  [('daro', 'n'), ('joke', 'n'), ('virus', 'n'),...  HOAKS       Hoaks
# 4   [('pemerintah', 'n'), ('mewaspadai', 'n'), ('m...  FAKTA       Fakta
# 8   [('lawanvarianbaru', None), ('tanda', 'n'), ('...  FAKTA       Fakta
# 12  [('waspada', 'n'), ('virus', 'n'), ('corona', ...  HOAKS       Hoaks
# 1   [('smoga', 'n'), ('sj', 'n'), ('jd', 'n'), ('b...  HOAKS       Hoaks
# 16  [('viral', None), ('virus', 'n'), ('corona', '...  HOAKS       Hoaks
# 10  [('viral', None), ('virus', 'n'), ('corona', '...  HOAKS       Hoaks
# 7   [('kenaikan', 'n'), ('covid', 'n'), ('indonesi...  FAKTA       Fakta
# 1   [('virus', 'n'), ('corona', 'n'), ('covid', 'n...  FAKTA       Fakta
#
#                                               Artikel
# 0   tvOneapa penyebab varian baru virus corona kem...
# 13  Berita Coronavirus grismo varian baru corona m...
# 15  Woy. wuhan jiayou   virus corona menyebar lewa...
# 11  Janahara.comwaspada  virus corona menyebar lew...
# 7        Zidnia Pembayun  amp  bisnis vaksin pastinya
# 11  kominfomagetanjangan abai  jangan panik  tetap...
# 18  Aris Budi Sulistyovirus corona menyebar lewat ...
# 20  Rifaldi Raka Putravirus corona menyebar lewat ...
# 14  ridea tetap harus waspada dengan virus corona ...
# 14  Rina Syafrisoal virus corona menyebar lewat hp...
# 15  IndriDiana tetap harus waspada dengan virus co...
# 9   Khaedirmasa ada yang percaya sih virus corona ...
# 4                      71B bisnis vaksin ga diitung
# 9   detikcomvarian baru corona omicron ba   dan ba...
# 10  Tribun Medanada varian baru virus corona  indo...
# 6   LINIKINI_IDcommuters  hati hati ada varian bar...
# 3   Mandroid|Kaiwajar   komnas ini ada hanya utk m...
# 12  mami sarah tetap harus waspada dengan virus co...
# 5   Orasi.Id virus ohvirus  padahal kita bisa meno...
# 13          bagervirus corona menyebar lewat hp xiomi
# 0   HendraRoestoeMulyanasaya lebih percaya kpd dr ...
# 5   kumparanaturan ini akan berubah bila ada varia...
# 2   Berita Coronakenapa varian dan subvarian baru ...
# 8   Andi Pitopang bentar lagi bisnis vaksin cacar ...
# 2   Um Jihan logikanya  kenapa ke afrika  afrika d...
# 3   CNN Indonesiakenapa varian dan subvarian baru ...
# 17        6:00pmvirus corona menyebar lewat hp xiaomi
# 6   andriantoitu penjanjian tipuan yg di gunakan u...
# 19  Adi Saputradaro joke virus corona menyebar lew...
# 4   𝕬𝖐𝖇𝖆𝖗 pemerintah mewaspadai munculnya virus c...
# 8   Alin Tanlawanvarianbaru  tanda  omricon varian...
# 12  Endonesia.idwaspada  virus corona menyebar lew...
# 1   wahiidin smoga sj bukan jd bisnis  ada yg bila...
# 16  MSNIndonesiaviral virus corona menyebar lewat ...
# 10  Dif Zeinviral virus corona menyebar lewat hp x...
# 7   Nara€rameski kenaikan kasus covid    di indone...
# 1   VivaCoidvirus corona atau covid    terus bermu...

# %%
#Data Cleaning
from nltk.corpus import stopwords
import string

# %%
def process_text(s):

    # Check string to see if they are a punctuation
    nopunc = [char for char in s if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Convert string to lowercase and remove stopwords
    clean_string = [word for word in nopunc.split() if word.lower() not in stopwords.words('indonesian')]
    return clean_string

# %%
# Tokenize the text :Convert the normal text strings in to a list of tokens
news['Clean Text'] = news['Artikel'].apply(process_text)
print(type(news['Artikel']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
news.sample(5)
# Out:
#       created_at                 date              user_id         username  \
# 15  1.580277e+12  2020-01-29 12:48:06  1140215810230640640       apasihlex_
# 14  1.580283e+12  2020-01-29 14:27:56            163126674  RinaAnak_Bundaa
# 14  1.654571e+12  2022-06-07 09:58:11  1484076613566627842    ridea81837744
# 6   1.653612e+12  2022-05-27 07:42:00            366549945   andri_anto7121
# 10  1.580297e+12  2020-01-29 18:25:34  1101571504460840960          difzein
#
#            name                                              tweet  \
# 15         Woy.   wuhan jiayou   virus corona menyebar lewat hp...
# 14  Rina Syafri  soal virus corona menyebar lewat hp xiaomi  ik...
# 14        ridea   tetap harus waspada dengan virus corona varia...
# 6     andrianto  itu penjanjian tipuan yg di gunakan utk penghu...
# 10     Dif Zein  viral virus corona menyebar lewat hp xiaomi  i...
#
#                                                  link  \
# 15  https://twitter.com/apasihlex_/status/12223959...
# 14  https://twitter.com/RinaAnak_Bundaa/status/122...
# 14  https://twitter.com/ridea81837744/status/15340...
# 6   https://twitter.com/andri_anto7121/status/1529...
# 10  https://twitter.com/difzein/status/12224809037...
#
#                                            POS tagged  Label Fakta/Hoaks  \
# 15  [('wuhan', 'n'), ('jiayou', 'n'), ('virus', 'n...  HOAKS       Hoaks
# 14  [('virus', 'n'), ('corona', 'n'), ('menyebar',...  HOAKS       Hoaks
# 14  [('waspada', 'n'), ('virus', 'n'), ('corona', ...  FAKTA       Fakta
# 6   [('penjanjian', None), ('tipuan', 'n'), ('yg',...  HOAKS       Hoaks
# 10  [('viral', None), ('virus', 'n'), ('corona', '...  HOAKS       Hoaks
#
#                                               Artikel  \
# 15  Woy. wuhan jiayou   virus corona menyebar lewa...
# 14  Rina Syafrisoal virus corona menyebar lewat hp...
# 14  ridea tetap harus waspada dengan virus corona ...
# 6   andriantoitu penjanjian tipuan yg di gunakan u...
# 10  Dif Zeinviral virus corona menyebar lewat hp x...
#
#                                            Clean Text
# 15  [Woy, wuhan, jiayou, virus, corona, menyebar, ...
# 14  [Rina, Syafrisoal, virus, corona, menyebar, hp...
# 14   [ridea, waspada, virus, corona, varian, omicron]
# 6   [andriantoitu, penjanjian, tipuan, yg, utk, pe...
# 10  [Dif, Zeinviral, virus, corona, menyebar, hp, ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=process_text).fit(news['Clean Text'])

print(len(bow_transformer.vocabulary_)) #Total vocab words
# Out:
# 37

# %%
#Bag-of-Words (bow) transform the entire DataFrame of text
news_bow = bow_transformer.transform(news['Clean Text'])

# %%
print('Shape of Sparse Matrix: ', news_bow.shape)
print('Amount of Non-Zero occurences: ', news_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (37, 37)
# Amount of Non-Zero occurences:  37

# %%
sparsity = (100.0 * news_bow.nnz / (news_bow.shape[0] * news_bow.shape[1]))
print('sparsity: {}'.format(round(sparsity)))
# Out:
# sparsity: 3

# %%
#TF-IDF

from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer().fit(news_bow)
news_tfidf = tfidf_transformer.transform(news_bow)
print(news_tfidf)
print(type(news_tfidf))
print(news_tfidf.shape)
# Out:
#   (0, 34)	1.0
#   (1, 24)	1.0
#   (2, 6)	1.0
#   (3, 8)	1.0
#   (4, 36)	1.0
#   (5, 31)	1.0
#   (6, 15)	1.0
#   (7, 18)	1.0
#   (8, 3)	1.0
#   (9, 29)	1.0
#   (10, 22)	1.0
#   (11, 30)	1.0
#   (12, 32)	1.0
#   (13, 7)	1.0
#   (14, 33)	1.0
#   (15, 12)	1.0
#   (16, 11)	1.0
#   (17, 35)	1.0
#   (18, 23)	1.0
#   (19, 17)	1.0
#   (20, 1)	1.0
#   (21, 19)	1.0
#   (22, 27)	1.0
#   (23, 26)	1.0
#   (24, 4)	1.0
#   (25, 14)	1.0
#   (26, 9)	1.0
#   (27, 13)	1.0
#   (28, 10)	1.0
#   (29, 28)	1.0
#   (30, 21)	1.0
#   (31, 25)	1.0
#   (32, 16)	1.0
#   (33, 0)	1.0
#   (34, 5)	1.0
#   (35, 2)	1.0
#   (36, 20)	1.0
# <class 'scipy.sparse.csr.csr_matrix'>
# (37, 37)

# %%
#Train Naive Bayes Model
from sklearn.naive_bayes import MultinomialNB
import pickle
fakenews_detect_model = MultinomialNB().fit(news_tfidf, news['Fakta/Hoaks'])

# %%
#save multinominalNB to model

#Model Evaluation
predictions = fakenews_detect_model.predict(news_tfidf)
filename = 'fakenews_model.pkl'
pickle.dump(fakenews_detect_model, open(filename, 'wb'))
print(predictions)
# Out:
# ['Fakta' 'Fakta' 'Fakta' 'Fakta' 'Fakta' 'Fakta' 'Fakta' 'Fakta' 'Fakta'
#  'Fakta' 'Fakta' 'Fakta' 'Fakta' 'Fakta' 'Fakta' 'Fakta' 'Hoaks' 'Hoaks'
#  'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks'
#  'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks' 'Hoaks'
#  'Hoaks']

# %%
from sklearn.metrics import classification_report
print (classification_report(news['Fakta/Hoaks'], predictions))
# Out:
#               precision    recall  f1-score   support
#
#        Fakta       1.00      1.00      1.00        16
#        Hoaks       1.00      1.00      1.00        21
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37

# %%
from sklearn.model_selection import train_test_split

news_train, news_test, text_train, text_test = train_test_split(news['Artikel'], news['Fakta/Hoaks'], test_size=0.3)

print(len(news_train), len(news_test), len(news_train) + len(news_test))
print(text_test)
# Out:
# 25 12 37
# 8     Hoaks
# 12    Hoaks
# 15    Fakta
# 14    Fakta
# 13    Hoaks
# 6     Fakta
# 11    Fakta
# 7     Fakta
# 20    Hoaks
# 12    Fakta
# 15    Hoaks
# 8     Fakta
# Name: Fakta/Hoaks, dtype: object

# %%
#Create Data Pipeline

from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=process_text)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])
pipeline.fit(news_train,text_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function process_text at 0x000002C432C38F70>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
predictions = pipeline.predict(news_test)

# %%
print(classification_report(predictions,text_test))
# Out:
#               precision    recall  f1-score   support
#
#        Fakta       1.00      1.00      1.00         7
#        Hoaks       1.00      1.00      1.00         5
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(text_test, predictions)

# %%
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=['HOAKS', 'FAKTA'], yticklabels=['HOAKS', 'FAKTA'], cmap=plt.cm.Blues, cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

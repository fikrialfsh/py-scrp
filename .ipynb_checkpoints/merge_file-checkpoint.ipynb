# %%
import pandas as pd

# %%
data1 = pd.read_csv('labeled_tweets_varian baru.csv')
# data2 = pd.read_csv('labeled_tweets_virus corona menyebar lewat hp.csv')

# %%
data1.drop(data1[data1['Label'] == 0].index, inplace = True)
data1
# Out:
#       created_at                 date              user_id         username  \
# 0   1.655545e+12  2022-06-18 16:42:27             55507370        tvOneNews
# 1   1.655512e+12  2022-06-18 07:19:23             41730943         VIVAcoid
# 3   1.655211e+12  2022-06-14 19:53:52   705224376422010881    Berita_Corona
# 4   1.655210e+12  2022-06-14 19:40:52             17128975     CNNIndonesia
# 5   1.655183e+12  2022-06-14 12:06:11  1403680930842042374       BroAkbar27
# 6   1.655174e+12  2022-06-14 09:32:06   759692754985242625         kumparan
# 7   1.655171e+12  2022-06-14 08:50:27           2890721762      LINIKINI_ID
# 8   1.655169e+12  2022-06-14 08:17:09  1351236840066609171         Naraera1
# 9   1.655169e+12  2022-06-14 08:03:19  1068779253351632896       Alin_tan11
# 10  1.655130e+12  2022-06-13 21:15:09             69183155         detikcom
# 11  1.655117e+12  2022-06-13 17:50:24            142305302      tribunmedan
# ...

# %%
# data2.drop(data2[data2['Label'] == 0].index, inplace = True)
# data2

# %%
# frames = [data1, data2] 
# result = pd.concat(frames).drop_duplicates().reset_index(drop=True)
# result

# %%
label = []
for index, row in data1.iterrows():
    if row['Label'] == 1:
        label.append('FAKTA')
    else:
        label.append('HOAKS')
data1['Label'] = label
data1
# Out:
#       created_at                 date              user_id         username  \
# 0   1.655545e+12  2022-06-18 16:42:27             55507370        tvOneNews
# 1   1.655512e+12  2022-06-18 07:19:23             41730943         VIVAcoid
# 3   1.655211e+12  2022-06-14 19:53:52   705224376422010881    Berita_Corona
# 4   1.655210e+12  2022-06-14 19:40:52             17128975     CNNIndonesia
# 5   1.655183e+12  2022-06-14 12:06:11  1403680930842042374       BroAkbar27
# 6   1.655174e+12  2022-06-14 09:32:06   759692754985242625         kumparan
# 7   1.655171e+12  2022-06-14 08:50:27           2890721762      LINIKINI_ID
# 8   1.655169e+12  2022-06-14 08:17:09  1351236840066609171         Naraera1
# 9   1.655169e+12  2022-06-14 08:03:19  1068779253351632896       Alin_tan11
# 10  1.655130e+12  2022-06-13 21:15:09             69183155         detikcom
# 11  1.655117e+12  2022-06-13 17:50:24            142305302      tribunmedan
# ...

# %%
data1.to_csv("true_dataset.csv", index=False)
